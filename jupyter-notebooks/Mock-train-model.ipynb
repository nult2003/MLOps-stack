# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-3.5.1-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==3.5.1 (from mlflow)
#   Downloading mlflow_skinny-3.5.1-py3-none-any.whl.metadata (31 kB)
# Collecting mlflow-tracing==3.5.1 (from mlflow)
#   Downloading mlflow_tracing-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/conda/lib/python3.11/site-packages (from mlflow) (1.12.0)
# Collecting cryptography<47,>=43.0.0 (from mlflow)
#   Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /opt/conda/lib/python3.11/site-packages (from mlflow) (3.8.0)
# Requirement already satisfied: numpy<3 in /opt/conda/lib/python3.11/site-packages (from mlflow) (1.24.4)
# Requirement already satisfied: pandas<3 in /opt/conda/lib/python3.11/site-packages (from mlflow) (2.1.1)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow) (13.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/conda/lib/python3.11/site-packages (from mlflow) (1.3.1)
# Requirement already satisfied: scipy<2 in /opt/conda/lib/python3.11/site-packages (from mlflow) (1.11.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from mlflow) (2.0.22)
# Collecting cachetools<7,>=5.0.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading cachetools-6.2.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.0.0)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading databricks_sdk-0.69.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading fastapi-0.119.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (3.1.40)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (6.8.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging<26 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (23.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (4.24.3)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (2.31.0)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from mlflow-skinny==3.5.1->mlflow) (4.8.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow) (1.2.4)
# Collecting cffi>=2.0.0 (from cryptography<47,>=43.0.0->mlflow)
#   Downloading cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from docker<8,>=4.0.0->mlflow) (2.0.7)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow) (3.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from Flask<4->mlflow) (2.1.3)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/conda/lib/python3.11/site-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3->mlflow) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.11/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.21)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting starlette<0.49.0,>=0.40.0 (from fastapi<1->mlflow-skinny==3.5.1->mlflow)
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.5.1->mlflow) (3.17.0)
# Collecting protobuf<7,>=3.12.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow)
#   Downloading pydantic_core-2.41.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.5.1->mlflow)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.10.8->mlflow-skinny==3.5.1->mlflow)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.5.1->mlflow) (2023.7.22)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==3.5.1->mlflow)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.5.1->mlflow) (3.0.5)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/conda/lib/python3.11/site-packages (from starlette<0.49.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow) (4.0.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette<0.49.0,>=0.40.0->fastapi<1->mlflow-skinny==3.5.1->mlflow) (1.3.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.5.1->mlflow)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading mlflow-3.5.1-py3-none-any.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 1.6 MB/s eta 0:00:0000:0100:010m
# Downloading mlflow_skinny-3.5.1-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.6 MB/s eta 0:00:0000:0100:01
# Downloading mlflow_tracing-3.5.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.7 MB/s eta 0:00:00a 0:00:01
# Downloading cryptography-46.0.3-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 1.9 MB/s eta 0:00:00 0:00:01
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 1.8 MB/s eta 0:00:00 0:00:01
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Downloading cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading databricks_sdk-0.69.0-py3-none-any.whl (749 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 749.8/749.8 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading fastapi-0.119.1-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 1.6 MB/s eta 0:00:00 0:00:01
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 1.4 MB/s eta 0:00:00 0:00:01
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-6.33.0-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 1.0 MB/s eta 0:00:0000:0100:01m
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_core-2.41.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.2 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.5 MB/s eta 0:00:00
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.3/221.3 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: werkzeug, typing-extensions, sqlparse, python-dotenv, pyasn1, protobuf, itsdangerous, h11, gunicorn, graphql-core, cffi, cachetools, blinker, annotated-types, uvicorn, typing-inspection, starlette, rsa, pydantic-core, pyasn1-modules, opentelemetry-proto, opentelemetry-api, graphql-relay, Flask, docker, cryptography, pydantic, opentelemetry-semantic-conventions, graphene, google-auth, Flask-CORS, opentelemetry-sdk, fastapi, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
#   Attempting uninstall: cffi
#     Found existing installation: cffi 1.16.0
#     Uninstalling cffi-1.16.0:
#       Successfully uninstalled cffi-1.16.0
#   Attempting uninstall: blinker
#     Found existing installation: blinker 1.6.3
#     Uninstalling blinker-1.6.3:
#       Successfully uninstalled blinker-1.6.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 41.0.4
#     Uninstalling cryptography-41.0.4:
#       Successfully uninstalled cryptography-41.0.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyopenssl 23.2.0 requires cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0, but you have cryptography 46.0.3 which is incompatible.
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 annotated-types-0.7.0 blinker-1.9.0 cachetools-6.2.1 cffi-2.0.0 cryptography-46.0.3 databricks-sdk-0.69.0 docker-7.1.0 fastapi-0.119.1 google-auth-2.41.1 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 h11-0.16.0 itsdangerous-2.2.0 mlflow-3.5.1 mlflow-skinny-3.5.1 mlflow-tracing-3.5.1 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 protobuf-6.33.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.3 pydantic-core-2.41.4 python-dotenv-1.1.1 rsa-4.9.1 sqlparse-0.5.3 starlette-0.48.0 typing-extensions-4.15.0 typing-inspection-0.4.2 uvicorn-0.38.0 werkzeug-3.1.3

# %%
import mlflow
import numpy as np
import pickle
import os

# === KHẮC PHỤC: Sử dụng thư mục mlruns cục bộ ===
# Tạo thư mục mlruns nếu nó chưa tồn tại (chỉ cần trong JupyterLab)
MLRUNS_DIR = os.path.join("..", "mlruns")
if not os.path.exists(MLRUNS_DIR):
    os.makedirs(MLRUNS_DIR)
    
# Đảm bảo nơi lưu MLflow có quyền ghi
mlflow.set_tracking_uri("http://10.89.0.13:5000")
print(f"Tracking URI set to: {mlflow.get_tracking_uri()}")

mlflow.set_experiment("Integration Test")

class MockModel:
    def predict(self, x):
        return x * 2

mock_model = MockModel()

with mlflow.start_run(run_name="mock_training_run") as run:
    mlflow.log_param("test_size", 0.2)
    mlflow.log_metric("mock_accuracy", 0.99)
    
    # === LƯU TỆP VÀO THƯ MỤC MLRUNS CỤC BỘ ===
    # Đặt tệp trong thư mục tạm thời, bên trong thư mục mlruns đã được mount
    model_path = os.path.join(MLRUNS_DIR, "mock_model.pkl")
    with open(model_path, "wb") as f:
        pickle.dump(mock_model, f)
    
    mlflow.log_artifact(model_path, artifact_path="model")
    
    print(f"Run ID: {run.info.run_id}")
    print("Model artifact logged successfully.")
# Out:
# Tracking URI set to: http://10.89.0.13:5000
# Run ID: 7bb12d6246634a319e32131392628f1b
# Model artifact logged successfully.
# 🏃 View run mock_training_run at: http://10.89.0.13:5000/#/experiments/1/runs/7bb12d6246634a319e32131392628f1b
# 🧪 View experiment at: http://10.89.0.13:5000/#/experiments/1
